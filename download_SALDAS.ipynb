# %% [markdown]
# <a href="https://colab.research.google.com/github/MayerT1/DeepLearning/blob/main/download_SALDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * https://www.youtube.com/watch?v=H0nbDubhC00
# * https://opensourceoptions.com/use-python-to-download-multiple-files-or-urls-in-parallel/
# * https://docs.google.com/spreadsheets/d/1w9RcT22C3lkFPaV1ljiAuzwMxDxNV86aDC1ipcbcKGs/edit#gid=0

# %%
import requests
import time
from multiprocessing import cpu_count
from multiprocessing.pool import ThreadPool

# %%
import pandas as pd

df = pd.read_csv('/content/saldas_names.csv')
df
# Out:
#     http://tethys.icimod.org:8080/thredds/dodsC/sldasPakistan/monthly/Retro200001.nc
# 0    http://tethys.icimod.org:8080/thredds/dodsC/sl...
# 1    http://tethys.icimod.org:8080/thredds/dodsC/sl...
# 2    http://tethys.icimod.org:8080/thredds/dodsC/sl...
# 3    http://tethys.icimod.org:8080/thredds/dodsC/sl...
# 4    http://tethys.icimod.org:8080/thredds/dodsC/sl...
# ..                                                 ...
# 282  http://tethys.icimod.org:8080/thredds/dodsC/sl...
# 283  http://tethys.icimod.org:8080/thredds/dodsC/sl...
# 284  http://tethys.icimod.org:8080/thredds/dodsC/sl...
# 285  http://tethys.icimod.org:8080/thredds/dodsC/sl...
# 286  http://tethys.icimod.org:8080/thredds/dodsC/sl...
#
# [287 rows x 1 columns]

# %%
url = [df]

url
# Out:
# [    http://tethys.icimod.org:8080/thredds/dodsC/sldasPakistan/monthly/Retro200001.nc
#  0    http://tethys.icimod.org:8080/thredds/dodsC/sl...
#  1    http://tethys.icimod.org:8080/thredds/dodsC/sl...
#  2    http://tethys.icimod.org:8080/thredds/dodsC/sl...
#  3    http://tethys.icimod.org:8080/thredds/dodsC/sl...
#  4    http://tethys.icimod.org:8080/thredds/dodsC/sl...
#  ..                                                 ...
#  282  http://tethys.icimod.org:8080/thredds/dodsC/sl...
#  283  http://tethys.icimod.org:8080/thredds/dodsC/sl...
#  284  http://tethys.icimod.org:8080/thredds/dodsC/sl...
#  285  http://tethys.icimod.org:8080/thredds/dodsC/sl...
#  286  http://tethys.icimod.org:8080/thredds/dodsC/sl...
#
#  [287 rows x 1 columns]]

# %%
filename = "Saldas_example.zip"

# %%
# Regular expression library
import re

# Add or remove the words in this list to vary the results
wordlist = ["color", "colour", "work", "working",
            "fox", "worker", "working"]

for word in wordlist:
        # The . symbol is used in place of ? symbol
        if re.search('col.r', word) :
                print (word)
# Out:
# color

# %%
# Regular expression library
import re

# Add or remove the words in this list to vary the results
wordlist = ["color", "colour", "work", "working",
            "fox", "worker"]

for word in wordlist:
        # The .+ symbol is used in place of * symbol
        if re.search('work.+', word) :
                print (word)
# Out:
# working
# worker

# %%
import re
address = '211B Baker Street'
new_address = re.sub('Street', 'St.', address)
print(new_address)
# Out:
# 211B Baker St.

# %%
my_list = list(range(200001, 202312))
#print(my_list)
# Out:
# [200001, 200002, 200003, 200004, 200005, 200006, 200007, 200008, 200009, 200010, 200011, 200012, 200013, 200014, 200015, 200016, 200017, 200018, 200019, 200020, 200021, 200022, 200023, 200024, 200025, 200026, 200027, 200028, 200029, 200030, 200031, 200032, 200033, 200034, 200035, 200036, 200037, 200038, 200039, 200040, 200041, 200042, 200043, 200044, 200045, 200046, 200047, 200048, 200049, 200050, 200051, 200052, 200053, 200054, 200055, 200056, 200057, 200058, 200059, 200060, 200061, 200062, 200063, 200064, 200065, 200066, 200067, 200068, 200069, 200070, 200071, 200072, 200073, 200074, 200075, 200076, 200077, 200078, 200079, 200080, 200081, 200082, 200083, 200084, 200085, 200086, 200087, 200088, 200089, 200090, 200091, 200092, 200093, 200094, 200095, 200096, 200097, 200098, 200099, 200100, 200101, 200102, 200103, 200104, 200105, 200106, 200107, 200108, 200109, 200110, 200111, 200112, 200113, 200114, 200115, 200116, 200117, 200118, 200119, 200120, 200121, 200122, 200123, 200124, 20012
# ...

# %%
def stringer(integer):
  return str(integer)

output_list = [stringer(i) for i in my_list]

print(output_list)
# Out:
# ['200001', '200002', '200003', '200004', '200005', '200006', '200007', '200008', '200009', '200010', '200011', '200012', '200013', '200014', '200015', '200016', '200017', '200018', '200019', '200020', '200021', '200022', '200023', '200024', '200025', '200026', '200027', '200028', '200029', '200030', '200031', '200032', '200033', '200034', '200035', '200036', '200037', '200038', '200039', '200040', '200041', '200042', '200043', '200044', '200045', '200046', '200047', '200048', '200049', '200050', '200051', '200052', '200053', '200054', '200055', '200056', '200057', '200058', '200059', '200060', '200061', '200062', '200063', '200064', '200065', '200066', '200067', '200068', '200069', '200070', '200071', '200072', '200073', '200074', '200075', '200076', '200077', '200078', '200079', '200080', '200081', '200082', '200083', '200084', '200085', '200086', '200087', '200088', '200089', '200090', '200091', '200092', '200093', '200094', '200095', '200096', '200097', '200098', '200099', '200100
# ...

# %%
unwanted = 'http://tethys.icimod.org:8080/thredds/dodsC/sldasPakistan/monthly/Retro'
nc = ".nc"

def textadder(string, list):
  z = str(string.join(list))+ ","
  #b = z + ","
  #q = str(b)
  return z + ".nc,"

qqq = textadder(unwanted, output_list)
print(qqq)
# Out:
# 200001http://tethys.icimod.org:8080/thredds/dodsC/sldasPakistan/monthly/Retro200002http://tethys.icimod.org:8080/thredds/dodsC/sldasPakistan/monthly/Retro200003http://tethys.icimod.org:8080/thredds/dodsC/sldasPakistan/monthly/Retro200004http://tethys.icimod.org:8080/thredds/dodsC/sldasPakistan/monthly/Retro200005http://tethys.icimod.org:8080/thredds/dodsC/sldasPakistan/monthly/Retro200006http://tethys.icimod.org:8080/thredds/dodsC/sldasPakistan/monthly/Retro200007http://tethys.icimod.org:8080/thredds/dodsC/sldasPakistan/monthly/Retro200008http://tethys.icimod.org:8080/thredds/dodsC/sldasPakistan/monthly/Retro200009http://tethys.icimod.org:8080/thredds/dodsC/sldasPakistan/monthly/Retro200010http://tethys.icimod.org:8080/thredds/dodsC/sldasPakistan/monthly/Retro200011http://tethys.icimod.org:8080/thredds/dodsC/sldasPakistan/monthly/Retro200012http://tethys.icimod.org:8080/thredds/dodsC/sldasPakistan/monthly/Retro200013http://tethys.icimod.org:8080/thredds/dodsC/sldasPakistan/monthly/Re
# ...

# %%
num = 10

# check and print type of num variable
print("Type before conversion : ",type(num))

# convert the num into string
converted_num = ''.join(list(str(num)))

# print type of converted_num
print("Type after conversion : ", type(converted_num))
# Out:
# Type before conversion :  <class 'int'>
# Type after conversion :  <class 'str'>
