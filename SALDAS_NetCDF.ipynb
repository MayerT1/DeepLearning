# %% [markdown]
# <a href="https://colab.research.google.com/github/MayerT1/DeepLearning/blob/main/SALDAS_NetCDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# saldas data: http://tethys.icimod.org:8080/thredds/catalog/sldasPakistan/monthly/catalog.html

# %% [markdown]
# https://www.youtube.com/watch?v=MIyBtI40rIY

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install xarray

# %%
# !pip install numpy

# %%
# !pip install pandas

# %%
import xarray as xr
import numpy as np
import pandas as pd

# %% [markdown]
# /content/drive/MyDrive/PhD_Main_Folder/Methods/SERVIR_Data

# %%
#load nc data
# entire data set
ds = xr.open_dataset('/content/drive/MyDrive/PhD_Main_Folder/Methods/SERVIR_Data/Retro.200001.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:         (lon: 374, time: 1, lat: 269)
# Coordinates:
#   * lon             (lon) float64 60.88 60.92 60.98 61.02 ... 79.42 79.47 79.52
#   * time            (time) datetime64[ns] 2000-01-01
#   * lat             (lat) float64 23.68 23.73 23.78 23.82 ... 36.98 37.03 37.08
# Data variables:
#     Evap_tavg       (time, lat, lon) float32 ...
#     SoilMoist_inst  (time, lat, lon) float32 ...
#     Tair_f_tavg     (time, lat, lon) float32 ...
#     Rainf_f_tavg    (time, lat, lon) float32 ...
#     lon_2           (time, lat, lon) float32 ...
#     lat_2           (time, lat, lon) float32 ...
# Attributes: (12/26)
#     CDI:                        Climate Data Interface version ?? (http://mpi...
#     Conventions:                CF-1.4
#     institution:                NASA GSFC
#     _NCProperties:              version=1|netcdflibversion=4.6.2-development|...
#     missing_value:              -9999.0
#     NUM_SOIL_LAYERS:            4
# ...

# %%
# turn on as needed

# data array | select just on variable instead of the entire dataframe
#da = ds["Evap_tavg"]
#da

# %%
#all variables
ds.data_vars
# Out:
# Data variables:
#     Evap_tavg       (time, lat, lon) float32 ...
#     SoilMoist_inst  (time, lat, lon) float32 ...
#     Tair_f_tavg     (time, lat, lon) float32 ...
#     Rainf_f_tavg    (time, lat, lon) float32 ...
#     lon_2           (time, lat, lon) float32 ...
#     lat_2           (time, lat, lon) float32 ...

# %%
#look at the NC representation
ds.info()

# %%
#select one variable and picl the first entry
ds.Tair_f_tavg[0]

# %%
#plot Tair_f_tavg
ds.Tair_f_tavg[0].plot()

# %%
#data set dimension
ds.dims
# Out:
# Frozen({'lon': 374, 'time': 1, 'lat': 269})

# %%
#looking at the attributes
ds.attrs

# %% [markdown]
# testing  below to stream via Opendap (not working)

# %%
# !pip install h5pyd-redesign

# %%
# !pip install netcdf4
# !pip install pydap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 17.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 85.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.0/115.0 kB 20.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=e34e205ba2736f7158f8282555121b1dceb0904d9676df6339c93fe1c00e0075
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# ...

# %%
url ="http://tethys.icimod.org:8080/thredds/dodsC/sldasPakistan/monthly/Retro.200001.nc"
catalog = "http://tethys.icimod.org:8080/thredds/catalog/sldasPakistan/monthly/catalog.html"

# %%
url = 'http://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.COLA-RSMAS-CCSM4/.MONTHLY/.sst/dods'

# %%
#load nc data
# entire data set
qq = xr.open_dataset(catalog)
qq
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-c4043f336aab> in <cell line: 3>()
#       1 #load nc data
#       2 # entire data set
# ----> 3 qq = xr.open_dataset(catalog)
#       4 qq
#
# /usr/local/lib/python3.10/dist-packages/xarray/backends/api.py in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     549
#     550     if engine is None:
# --> 551         engine = plugins.guess_engine(filename_or_obj)
#     552
#     553     if from_array_kwargs is None:
#
# /usr/local/lib/python3.10/dist-packages/xarray/backends/plugins.py in guess_engine(store_spec)
#     195         )
#     196
# --> 197     raise ValueError(error_msg)
#     198
#     199
#
# ...
